# %%
import cv2
import gym
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from skimage.metrics import structural_similarity as ssim
import torch

# %%
env = gym.make('MontezumaRevengeNoFrameskip-v4')

# %%
env.action_space
# Out:
# Discrete(18)

# %%
X = env.reset()
plt.imshow(X)

# %%
next_X = env.step(env.action_space.sample())[0]

# %%
def pre_proc(obs, h=84, w=84):
    obs = np.array(Image.fromarray(obs).convert('L')).astype('float32')
    return cv2.resize(obs, (h, w))

# %%
X = pre_proc(X)
next_X = pre_proc(next_X)

# %%
plt.imshow(X_processed, cmap='gray')

# %%
plt.imshow(next_X, cmap='gray')

# %%
ssim(X, next_X)
# Out:
# 0.9946518997090958
