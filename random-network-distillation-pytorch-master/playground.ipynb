# %%
import cv2
import gym
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import torch

# %%
env = gym.make('MontezumaRevengeNoFrameskip-v4')

# %%
env.action_space
# Out:
# Discrete(18)

# %%
X = env.reset()
plt.imshow(X)

# %%
X_processed = np.array(Image.fromarray(X).convert('L')).astype('float32')
X_processed = cv2.resize(X_processed, (84, 84))

# %%
plt.imshow(X_processed, cmap='gray')
